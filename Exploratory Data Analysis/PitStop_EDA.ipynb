# %%
# !pip install fastf1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.2/151.2 kB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 4.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websockets
#     Found existing installation: websockets 15.0.1
#     Uninstalling websockets-15.0.1:
#       Successfully uninstalled websockets-15.0.1
# ...

# %%
import pandas as pd
import numpy as np

# %%
pit = pd.read_csv('/content/Pit_Stop2.csv')
pit
# Out:
#       Year     Team Driver  LapNumber  Stint Compound  LapInStint  \
# 0     2018  Ferrari    VET          2      1     SOFT           1
# 1     2018  Ferrari    VET          3      1     SOFT           2
# 2     2018  Ferrari    VET          4      1     SOFT           3
# 3     2018  Ferrari    VET          5      1     SOFT           4
# 4     2018  Ferrari    VET          6      1     SOFT           5
# ...    ...      ...    ...        ...    ...      ...         ...
# 3249  2024  McLaren    PIA         74      2     HARD          73
# 3250  2024  McLaren    PIA         75      2     HARD          74
# 3251  2024  McLaren    PIA         76      2     HARD          75
# 3252  2024  McLaren    PIA         77      2     HARD          76
# 3253  2024  McLaren    PIA         78      2     HARD          77
#
#       StintLengthSoFar  LapTime(s)  LapTimeDelta  ...  StintDegradationSlope  \
# 0                    1      78.447         0.000  ...               0.300343
# ...
